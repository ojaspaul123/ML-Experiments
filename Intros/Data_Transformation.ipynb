# %% [markdown]
# <a href="https://colab.research.google.com/github/ojaspaul123/ML-Experiments/blob/main/Intros/Data_Transformation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
df = pd.read_csv('india_covid19_data.csv')
df.head()
# Out:
#      <input type="file" id="files-afae3350-2843-4d1a-9958-a37f16b86194" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-afae3350-2843-4d1a-9958-a37f16b86194">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.isnull().sum()
#df.shape
# Out:
# age          0
# gender       0
# fever        9
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
df['cough'].value_counts()
# Out:
# cough
# Yes    64
# No     34
# Name: count, dtype: int64

# %%
# %%markdown
# ---
# without COLOUMN TRANSFORM
# Out:
# ---
# without COLOUMN TRANSFORM

# %%
#train test split
from sklearn.model_selection import train_test_split
X= df.drop(columns = ['has_covid'])
y= df['has_covid']
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size =0.2)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((78, 5), (20, 5), (78,), (20,))

# %%
#Imputer
from sklearn.impute import SimpleImputer
si = SimpleImputer()
X_train_trf = si.fit_transform(X_train[['fever']])
X_test_trf = si.fit_transform(X_test[['fever']])

# %%
X_train_trf.shape
X_test_trf.shape
# Out:
# (20, 1)

# %%
#Categorical Encoding
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder(categories=[['Yes','No']])
X_train_cough = oe.fit_transform(X_train[['cough']])
X_test_cough = oe.fit_transform(X_test[['cough']])
X_train_cough.shape
# Out:
# (78, 1)

# %%
#OneHotEncoder
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(drop='first', sparse_output=False)
X_train_gender_city = ohe.fit_transform(X_train[['gender','city']])
X_test_gender_city = ohe.fit_transform(X_test[['gender','city']])
X_train_gender_city.shape
# Out:
# (78, 10)

# %%
X_train_age = X_train.drop(columns=['gender','fever','cough','city']).values
X_test_age = X_test.drop(columns=['gender','fever','cough','city']).values
X_train_age.shape
# Out:
# (78, 1)

# %%
#Concatenate
X_train_transformed = np.concatenate((X_train_age,X_train_cough,X_train_gender_city,X_train_trf),axis =1 )
X_train_transformed
# Out:
# array([[ 39.        ,   1.        ,   0.        , ...,   0.        ,
#           0.        ,  99.4       ],
#        [ 25.        ,   0.        ,   0.        , ...,   0.        ,
#           0.        , 102.6       ],
#        [ 38.        ,   0.        ,   0.        , ...,   0.        ,
#           0.        , 101.07428571],
#        ...,
#        [ 51.        ,   0.        ,   0.        , ...,   0.        ,
#           0.        , 103.9       ],
#        [ 44.        ,   0.        ,   1.        , ...,   0.        ,
#           1.        , 102.9       ],
#        [ 24.        ,   1.        ,   0.        , ...,   0.        ,
#           0.        ,  99.        ]])
