# %% [markdown]
# <a href="https://colab.research.google.com/github/ojaspaul123/ML-Experiments/blob/main/Intros/Data_Inputation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
df = pd.read_csv('Raw_Data.csv')
df.head()
# Out:
#      <input type="file" id="files-9697809d-93f7-4458-a9d0-be0655a829b2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9697809d-93f7-4458-a9d0-be0655a829b2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# A             2
# B             2
# C             2
# D             1
# dtype: int64

# %%
# %%markdown
# ---
# SIMPLE IMPUTER
# Out:
# ---
# SIMPLE IMPUTER

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy=  'mean')
df['A'] = imputer.fit_transform(df[['A']])

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# A             0
# B             2
# C             2
# D             1
# dtype: int64

# %%
imputer1 = SimpleImputer(strategy='median')
df['B'] = imputer1.fit_transform(df[['B']])
df
# Out:
#    Unnamed: 0      A    B    C     D
# 0           0  1.000  3.0  1.0   1.0
# 1           1  2.000  2.0  2.0   2.0
# 2           2  3.000  3.0  NaN   3.0
# 3           3  4.625  2.0  4.0   4.0
# 4           4  5.000  5.0  5.0   NaN
# 5           5  6.000  6.0  NaN   6.0
# 6           6  3.000  3.0  3.0   7.0
# 7           7  4.625  3.0  4.0   8.0
# 8           8  8.000  3.0  4.0   9.0
# 9           9  9.000  9.0  9.0  10.0

# %%
imputer2 = SimpleImputer(strategy='most_frequent')
df['C'] = imputer2.fit_transform(df[['C']])
df
# Out:
#    Unnamed: 0      A    B    C     D
# 0           0  1.000  3.0  1.0   1.0
# 1           1  2.000  2.0  2.0   2.0
# 2           2  3.000  3.0  4.0   3.0
# 3           3  4.625  2.0  4.0   4.0
# 4           4  5.000  5.0  5.0   NaN
# 5           5  6.000  6.0  4.0   6.0
# 6           6  3.000  3.0  3.0   7.0
# 7           7  4.625  3.0  4.0   8.0
# 8           8  8.000  3.0  4.0   9.0
# 9           9  9.000  9.0  9.0  10.0

# %%
# User-input values
df.fillna(0)
# Out:
#    Unnamed: 0    A    B    C     D
# 0           0  1.0  0.0  1.0   1.0
# 1           1  2.0  2.0  2.0   2.0
# 2           2  3.0  3.0  0.0   3.0
# 3           3  0.0  2.0  4.0   4.0
# 4           4  5.0  5.0  5.0   0.0
# 5           5  6.0  6.0  0.0   6.0
# 6           6  3.0  3.0  3.0   7.0
# 7           7  0.0  3.0  4.0   8.0
# 8           8  8.0  0.0  4.0   9.0
# 9           9  9.0  9.0  9.0  10.0
